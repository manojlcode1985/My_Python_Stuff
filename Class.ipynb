# %%
# Class

class Flight:
    pass

# Class statement creates a new block
# The above eg. is the simplest form of class

# class is similar to def, it can occur anywhere in the code
# Note: It binds the class definition to a class name

# %%
# Now the above code any be imported as a module

from Class import Flight   # Here class is the file name Class.py

f = Flight()
print(f)

# %%
# Now to use the class Flight, we call its constructor Flight()
# Note: Here we do not have __init__ defined
# So calling class name as a Function, calls the constructor
# and the constructor returns the object which assigns to a name f

type(f)
# Out:
# __main__.Flight

# %%
# In Jupyter we are getting __main__.Flight
# But we should ideally get below output
# <class 'airtravel.Flight'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Lets add Instance methods to Flight class
# This will different from normal Methods ( these dont have self as first argument)
